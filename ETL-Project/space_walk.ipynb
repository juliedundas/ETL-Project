# %%
import pandas as pd
import csv
import numpy as np

# %%
space_walk = pd.read_csv('eva.csv')
space_walk
# Out:
#      EVA # Country                                  Crew      Vehicle  \
# 0      1.0     USA                              Ed White    Gemini IV
# 1      2.0     USA                           David Scott  Gemini VIII
# 2      3.0     USA                         Eugene Cernan  Gemini IX-A
# 3      4.0     USA                          Mike Collins     Gemini X
# 4      5.0     USA                          Mike Collins     Gemini X
# ..     ...     ...                                   ...          ...
# 369  366.0  Russia       Oleg Kononenko|Anton Shkaplerov  ISS Incr-30
# 370  367.0  Russia      Gennady Padalka|Yuri Malenchenko  ISS Incr-32
# 371  368.0  Russia      Pavel Vinogradov|Roman Romanenko  ISS Incr-35
# 372  369.0  Russia  Fyodor Yurchikhin|Alexander Misurkin  ISS Incr-36
# 373  370.0  Russia  Fyodor Yurchikhin|Alexander Misurkin  ISS Incr-36
#
#                   Date Duration  \
# 0           06/03/1965     0:36
# 1    March 16-17, 1966     0:00
# ...

# %%
dropped_space_walk = space_walk[space_walk['EVA #'].notna()]
dropped_space_walk
# Out:
#      EVA # Country                                  Crew      Vehicle  \
# 0      1.0     USA                              Ed White    Gemini IV
# 1      2.0     USA                           David Scott  Gemini VIII
# 2      3.0     USA                         Eugene Cernan  Gemini IX-A
# 3      4.0     USA                          Mike Collins     Gemini X
# 4      5.0     USA                          Mike Collins     Gemini X
# ..     ...     ...                                   ...          ...
# 369  366.0  Russia       Oleg Kononenko|Anton Shkaplerov  ISS Incr-30
# 370  367.0  Russia      Gennady Padalka|Yuri Malenchenko  ISS Incr-32
# 371  368.0  Russia      Pavel Vinogradov|Roman Romanenko  ISS Incr-35
# 372  369.0  Russia  Fyodor Yurchikhin|Alexander Misurkin  ISS Incr-36
# 373  370.0  Russia  Fyodor Yurchikhin|Alexander Misurkin  ISS Incr-36
#
#                   Date Duration  \
# 0           06/03/1965     0:36
# 1    March 16-17, 1966     0:00
# ...

# %%
buzz = dropped_space_walk[dropped_space_walk['Crew'].str.contains('Buzz')]
buzz
# Out:
#     EVA # Country                        Crew     Vehicle        Date  \
# 7     8.0     USA                 Buzz Aldrin  Gemini XII  11/12/1966
# 8     9.0     USA                 Buzz Aldrin  Gemini XII  11/13/1966
# 9    10.0     USA                 Buzz Aldrin  Gemini XII  11/14/1966
# 12   13.0     USA  Neil Armstrong|Buzz Aldrin   Apollo 11  07/20/1969
# 13   14.0     USA  Neil Armstrong|Buzz Aldrin   Apollo 11  07/20/1969
#
#    Duration                                            Purpose
# 7      2:29     Standup EVA.  Science tasks.  Took star photos
# 8      2:06  Attached tether between Agena and Gemini.  UV ...
# 9      0:55   Standup EVA.  Jettisoned equipment.  Took photos
# 12     2:32  First to walk on the moon.  Some trouble getti...
# 13     0:05  Jettison suit backpacks and equip to lighten a...

# %%
dropped_space_walk.to_csv('eva_format.csv', index=False)
