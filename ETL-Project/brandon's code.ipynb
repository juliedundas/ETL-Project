# %%
import os
import csv
import pandas as pd
import numpy as np

# %%
load_file = "astronauts.csv"

astronauts_df = pd.read_csv(load_file)

# %%
astronauts_df = astronauts_df.dropna(subset=['Missions'])
# astronauts_df = astronauts_df[astronauts_df['Year'].between(1998,2009)]
astronauts_df_split = astronauts_df["Name"].str.split(" ")
# astronauts_df_name = [astronauts_df_split[-1] for astronauts_df_split in astronauts_df_split]
astronauts_df_name = []
for astronauts_df_split in astronauts_df_split:
    if astronauts_df_split[-1] == "":
        astronauts_df_name.append(astronauts_df_split[-3])
    else:
        astronauts_df_name.append(astronauts_df_split[-1])
astronauts_df["Last Name"] = astronauts_df_name
astronauts_df = astronauts_df.dropna(subset=['Last Name'])

astronauts_df_split = astronauts_df["Name"].str.split(" ")
astronauts_df_first_name = [astronauts_df_split[0] for astronauts_df_split in astronauts_df_split]
astronauts_df["First Name"] = astronauts_df_first_name

astronauts_df["Full Name"] = astronauts_df["First Name"] + " " + astronauts_df["Last Name"]
astronauts_df
# Out:
#                    Name    Year  Group   Status Birth Date        Birth Place  \
# 0       Joseph M. Acaba  2004.0   19.0   Active  5/17/1967      Inglewood, CA
# 1        Loren W. Acton     NaN    NaN  Retired   3/7/1936       Lewiston, MT
# 2      James C. Adamson  1984.0   10.0  Retired   3/3/1946         Warsaw, NY
# 3       Thomas D. Akers  1987.0   12.0  Retired  5/20/1951      St. Louis, MO
# 4           Buzz Aldrin  1963.0    3.0  Retired  1/20/1930      Montclair, NJ
# ..                  ...     ...    ...      ...        ...                ...
# 349  Peter J. K. Wisoff  1990.0   13.0  Retired  8/16/1958        Norfolk, VA
# 350       David A. Wolf  1990.0   13.0  Retired  8/23/1956   Indianapolis, IN
# 352    Alfred M. Worden  1966.0    5.0  Retired   2/7/1932        Jackson, MI
# 353       John W. Young  1962.0    2.0  Retired  9/24/1930  San Francisco, CA
# 354     George D. Zamka  1998.0   17.0  Retired  6/29/1962    Jersey City, NJ
#
# ...

# %%
# astronauts_df
degree_count = astronauts_df.groupby("Undergraduate Major")
degree_count = degree_count["Name"].count()

undergrade_degree_df = pd.DataFrame(degree_count)
sort = undergrade_degree_df.sort_values("Name", ascending=False)
sort.head(10)
# Out:
#                           Name
# Undergraduate Major
# Aerospace Engineering       32
# Physics                     30
# Aeronautical Engineering    27
# Mechanical Engineering      26
# Electrical Engineering      20
# Engineering Science         13
# Mathematics                 11
# Engineering                 10
# Chemical Engineering         9
# Chemistry                    9

# %%
grad_degree_count = astronauts_df.groupby("Graduate Major")
grad_degree_count = grad_degree_count["Name"].count()

grad_degree_df = pd.DataFrame(grad_degree_count)
sort1 = grad_degree_df.sort_values("Name", ascending=False)
sort1.head(10)
# Out:
#                             Name
# Graduate Major
# Aeronautical Engineering      25
# Aerospace Engineering         20
# Physics                       14
# Medicine                      14
# Mechanical Engineering        12
# Electrical Engineering         8
# Aeronautics & Astronautics     6
# Aviation Systems               6
# Astronautics                   5
# Mechanical  Engineering        5

# %%
astronauts_df.to_csv('astronaut_format.csv', index=False)
